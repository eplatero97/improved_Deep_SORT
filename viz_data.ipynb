# %% [markdown]
# Visualize data of quadruplet loss

# %%
 
from siamese_dataloader import *
from siamese_net import *
from torch import nn
import torchvision.transforms as T
from torchvision.utils import make_grid

def show(imgs):
    fix, axs = plt.subplots(ncols=len(imgs), squeeze=False)
    for i, img in enumerate(imgs):
        img = T.ToPILImage()(img.to('cpu'))
        axs[0, i].imshow(np.asarray(img))
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# turn dictionary into namespace object
class Bunch(object):
  def __init__(self, adict):
    self.__dict__.update(adict)



training_dir = "/home/cougarnet.uh.edu/eeplater/Documents/GitHub/improved_Deep_SORT/data/object-tracking-crops-data/crops"
train_batch_size = 3



module = DeepSORTModule(training_dir, train_batch_size, miner = "quadruplet")
module.setup()
dl = module.train_dataloader()
batch = next(iter(dl)) 
anchor_batch, positive_batch, negative_batch,negative_batch2 = batch # each element is of shape: torch.Size([9,3,256,128])

# %%
show(anchor_batch)

# %%
show(positive_batch)

# %%
show(negative_batch)

# %%
show(negative_batch2)

# %% [markdown]
# Visualize batch of triplet loss

# %%
 
from siamese_dataloader import *
from siamese_net import *
from torch import nn
import torchvision.transforms as T
from torchvision.utils import make_grid

def show(imgs):
    fix, axs = plt.subplots(ncols=len(imgs), squeeze=False)
    for i, img in enumerate(imgs):
        img = T.ToPILImage()(img.to('cpu'))
        axs[0, i].imshow(np.asarray(img))
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# turn dictionary into namespace object
class Bunch(object):
  def __init__(self, adict):
    self.__dict__.update(adict)



training_dir = "/home/cougarnet.uh.edu/eeplater/Documents/GitHub/improved_Deep_SORT/data/object-tracking-crops-data/crops"
train_batch_size = 3



module = DeepSORTModule(training_dir, train_batch_size) 
module.setup()
dl = module.train_dataloader()
batch = next(iter(dl)) 
anchor_batch, positive_batch, negative_batch = batch # each element is of shape: torch.Size([9,3,256,128])
imgs = torch.split(anchor_batch, 1, 0) # shape of each element: torch.Size([1,3,256,128])
pil_imgs = [T.ToPILImage()(img.squeeze()) for img in imgs]
# Out:
# /home/cougarnet.uh.edu/eeplater/anaconda3/envs/deep_sort/lib/python3.6/site-packages/torchvision/transforms/transforms.py:1249: UserWarning: Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead
#   "Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead"

# %%
show(anchor_batch)

# %%
show(positive_batch)

# %%
show(negative_batch)

# %%
dl.__len__()
# Out:
# 14598

# %%
256*160
# Out:
# 40960
